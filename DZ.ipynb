# %% [markdown]
# Условие 1: Задача 1
# Постройте график
# Назовите график
# Сделайте именование оси x и оси y
# Сделайте выводы
#
# 1.1. Скачать следующие данные: kc-house-data и laptop_price

# %%
import pandas as pd
import matplotlib.pyplot as plt
dfh = pd.read_csv('kc-house-data.csv', encoding = 'latin-1')
dfh.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dfh.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
dfl = pd.read_csv('laptop_price.csv', encoding = 'latin-1')
dfl.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# 1.2. Изучите стоимости недвижимости

# %%
import seaborn as sns
import numpy as np

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
plt.hist(dfh['price'])
plt.xlabel('мил. у.е.')
plt.ylabel('Кол-во домов')
plt.title('Стоимость недвижимости');

# %%
dfh['price'].min(), dfh['price'].max()
# Out:
# (75000.0, 7700000.0)

# %% [markdown]
# 1.3. Изучите распределение квадратуры жилой

# %%
plt.hist(dfh['sqft_living']);
plt.xlabel('кв.м.')
plt.ylabel('Кол-во домов')
plt.title('Жилая площадь');

# %%
dfh['sqft_living'].min(), dfh['sqft_living'].max()
# Out:
# (290, 13540)

# %% [markdown]
# 1.4. Изучите распределение года постройки

# %%
plt.hist(dfh['yr_built']);
plt.xlabel('год')
plt.ylabel('Кол-во домов')
plt.title('Год постройки');

# %% [markdown]
# Условие 2: 2 задача
# 2.1. Изучите распределение домов от наличия вида на набережную
# Постройте график
# Сделайте выводы

# %%
data = dfh['waterfront'].value_counts()
plt.pie(data.values, labels=data.index, autopct='%1.2f%%')
plt.legend(data.index);

# %% [markdown]
# 2.2. Изучите распределение этажей домов

# %%
data = dfh['floors'].value_counts()
plt.pie(data.values, labels=data.index, autopct='%1.2f%%')
plt.legend(data.index);

# %% [markdown]
# 2.3. Изучите распределение состояния домов

# %%
data = dfh['condition'].value_counts()
#plt.pie(data.values, labels=data.index, autopct='%1.2f%%')
#plt.legend(data.index);
data
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %%
plt.pie(data.values, labels=data.index, autopct='%1.2f%%')
plt.legend(data.index);

# %%
plt.hist(dfh['condition']);
plt.xlabel('Оценка состояния')
plt.ylabel('Кол-во домов')
plt.title('Состояние домов');

# %% [markdown]
# Условие 3: 3 задача
# Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости, с применением не менее 5 диаграмм из урока.
# Анализ сделайте в формате storytelling: дополнить каждый график письменными выводами и наблюдениями.
#
# Данная промежуточная аттестация оценивается по системе "зачет" / "не зачет".
# "Зачет" ставится, если слушатель успешно выполнил 3 или 2 критерия.
# "Незачет" ставится, если слушатель успешно выполнил 1 или меньше критериев.
#
# Критерии оценивания:
# - слушатель верно подгрузил данные в библиотеку
# - слушатель сформировал корректный график по данным
# - слушатель проанализировал данные и сделал корректный вывод

# %%
sns.boxplot(x=dfh['price'], y=dfh['view'], showfliers=True);

# %% [markdown]
# выглядит неочень( возможно, дело в типе данных
# не нашел как менять тип данных, по этому добавим еще пару столюцов

# %%
df = dfh
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
sns.boxplot(x=dfh['view'], y=dfh['price'], showfliers=True);

# %% [markdown]
# ого, поменял х с у местами и заработало, правда не совсем то что ожидал, но все же видно что стоимость жилья зависит от вида))

# %%
sns.boxplot(x=dfh['waterfront'], y=dfh['price'], showfliers=True);

# %% [markdown]
# И от нахождения моря тоже цена зависит, тут даже нагляднее, но опять же много вылетов, скорее всего из-за того, что нужно рассматривать не стоимость жилья, а квадратный метр

# %%
df['sc_metr_price'] = df['price']/df['sqft_lot']
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_basement  \
# 0             1180      5650     1.0           0     0  ...              0
# ...

# %%
df.drop(columns='sc_metr')
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_basement  \
# 0             1180      5650     1.0           0     0  ...              0
# ...

# %%
df['sc_metr_price_life'] = df['price']/df['sqft_living']
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_built  \
# 0             1180      5650     1.0           0     0  ...      1955
# ...

# %% [markdown]
# посмотрим теперь те же графики, но уже с ценой на квадратный метр

# %%
sns.boxplot(x=df['view'], y=df['sc_metr_price'], showfliers=True);

# %% [markdown]
# хмммм... вылеты не изменились(((

# %%
sns.boxplot(x=df['view'], y=df['sc_metr_price_life'], showfliers=True);

# %% [markdown]
# с жилой площадью чуть симпатичнее, но тоже не все гладео(

# %%
sns.boxplot(x=df['waterfront'], y=df['sc_metr_price'], showfliers=True);

# %%
sns.boxplot(x=df['waterfront'], y=df['sc_metr_price_life'], showfliers=True);

# %% [markdown]
# опять же много вылетов, но очевидно, что с видом на море цена явно выше, а вылеты скорее всего из-за состояния жилья, что мы теперь и проверим

# %%
sns.boxplot(x=df['condition'], y=df['price'], showfliers=True);

# %% [markdown]
# просто цена не о многом говорит, хотя зависимость и очевидна, попробуем снова квадратные метры

# %%
sns.boxplot(x=df['condition'], y=df['sc_metr_price'], showfliers=True);

# %% [markdown]
# тоже малопоказательно, жаль что не показан процент который попадает в "непопадает"

# %%
sns.boxplot(x=df['condition'], y=df['sc_metr_price_life'], showfliers=True);

# %% [markdown]
# А вот с жилыми ме трами еще интереснее, точнее сказать непонятнее)))
# попробуем оценить дизайн

# %%
sns.boxplot(x=df['grade'], y=df['price'], showfliers=True);

# %% [markdown]
# вообще прекрасно, даже не ожидал такого, очень наглядно, хотя и смешно, что основная ценность дома зависит в большей степени от дизайна)))

# %%
sns.boxplot(x=df['grade'], y=df['sc_metr_price'], showfliers=True);

# %% [markdown]
#  а вот в квадратных метрах уже не так все очевидно

# %%
sns.boxplot(x=df['grade'], y=df['sc_metr_price_life'], showfliers=True);

# %% [markdown]
# а в квадратных метрах жилой площади и вовсе все загадочно

# %%
df.iloc[:100].plot.scatter(x='date',y='price');

# %%
df.iloc[:100].plot.scatter(x='date',y='sc_metr_price');

# %%
df.iloc[:100].plot.scatter(x='date',y='sc_metr_price_life');
plt.xticks(rotation=90);

# %% [markdown]
# забавно, но от даты продажи ничего не зависит, словно цены законсервированны, хотя возможно просто временные рамки не так уж и широки

# %%
df['yearrr'] = df['date'].str[:4]
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  yr_renovated  \
# 0             1180      5650     1.0           0     0  ...             0
# ...

# %%
df.iloc[:100].plot.scatter(x='yearrr',y='sc_metr_price');

# %% [markdown]
# еще забавнее, все подещивело

# %%
df.iloc[:100].plot.scatter(x='yearrr',y='price');

# %% [markdown]
# ну и еще на последок проверим зависимость от года постройки, тут то явно должен прослеживаться тренд

# %%
df.iloc[:100].plot.scatter(x='yr_built',y='sc_metr_price_life');
plt.xticks(rotation=90);

# %% [markdown]
# Увы и ах никакого тренда, возможно, если все предыдущие графики выстроить по годам постройки дома то будет выслеживаться хоть какая-то тенденция, но на данный момент с меня хватит, и так потратил больше времени чем планировал, хотя было интересно
